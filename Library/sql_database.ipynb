# %%
#import mysql.connector

# %% [markdown]
# ## Store datasets in database in sql

# %%
import pandas as pd

# %% [markdown]
# ### load dataframes

# %%
books = pd.read_pickle("Data/books_with_section.p")
books
# Out:
#                                           authors  \
# 0                                    The Try Guys
# 1               Stephen Hawking, Leonard Mlodinow
# 2       James Harkin, John Lloyd, John Mitchinson
# 3                             The Muffin Brothers
# 4                                   Running Press
# ...                                           ...
# 806567                             Pocket Puzzles
# 806568                             Pocket Puzzles
# 806569                             Pocket Puzzles
# 806570                             Pocket Puzzles
# 806571                             Pocket Puzzles
#
#                                       categories  \
# 0                                   [2813, 2980]
# 1                                   [1520, 1532]
# 2                              [377, 2978, 2980]
# 3                             [2859, 2980, 2983]
# 4                             [2980, 2452, 2540]
# ...                                          ...
# ...

# %%
students = pd.read_pickle("Data/students.p")
students.dtypes
# Out:
# student_id           int64
# password             int64
# total_time_spent     int64
# past_seats          object
# past_books          object
# current_seat         int64
# time_spent           int64
# email               object
# dtype: object

# %%
layout = pd.read_pickle("Data/layout.p")
layout.dtypes
# Out:
# ID                 int64
# Type              object
# x                float64
# y                float64
# z                  int64
# Area              object
# Window             int64
# Computer           int64
# xy array          object
# dist_toilet      float64
# dist_elevator    float64
# dist_stairs      float64
# dtype: object

# %%
seats = pd.read_csv("Data/seats.csv").drop(columns="Unnamed: 0")
seats#.dtypes
# Out:
#       ID  Type    x    y  z Area  Window  Computer   xy array  dist_toilet  \
# 0      1  seat  0.5  0.5  0    A       1         1  [0.5 0.5]     3.535534
# 1      2  seat  1.5  0.5  0    A       1         1  [1.5 0.5]     2.549510
# 2      3  seat  2.5  0.5  0    A       1         1  [2.5 0.5]     1.581139
# 3      4  seat  3.5  0.5  0    A       1         1  [3.5 0.5]     0.707107
# 4      5  seat  0.5  1.5  0    A       1         1  [0.5 1.5]     3.807887
# ..   ...   ...  ...  ... ..  ...     ...       ...        ...          ...
# 99   100  seat  5.5  8.5  1    H       0         1  [5.5 8.5]     8.631338
# 100  101  seat  6.5  8.5  1    H       0         1  [6.5 8.5]     8.860023
# 101  102  seat  4.5  9.5  1    H       1         1  [4.5 9.5]     9.513149
# 102  103  seat  5.5  9.5  1    H       1         1  [5.5 9.5]     9.617692
# 103  104  seat  6.5  9.5  1    H       1         1  [6.5 9.5]     9.823441
#
#      dist_elevator  dist_stairs  taken  code
# ...

# %% [markdown]
# ### sql tables

# %%
# cnx = mysql.connector.connect(user="root",
#                         password = "Lissabon22",
#                         host = "localhost")

# # establish connection to a database

# %%
# cnx.is_connected()
# Out:
# True

# %%
# cursor = cnx.cursor()
# cursor

# %%
#query = """CREATE DATABASE paideia;"""

# %%
#cursor.execute(query)

# %%
# import the module
from sqlalchemy import create_engine

# create sqlalchemy engine
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw="Lissabon22",
                               db="paideia"))

# %%
len(books["id"].unique())
# Out:
# 806572

# %%
len(books.index)
# Out:
# 806572

# %%
books['format'] = books['format'].astype(str)

# %%
books.to_sql('books', con = engine, if_exists = 'append', chunksize = 100000)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/opt/anaconda3/envs/finalproject/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1788, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///Users/medea/opt/anaconda3/envs/finalproject/lib/python3.9/site-packages/sqlalchemy/engine/base.py?line=1786'>1787</a>     if not evt_handled:
# -> <a href='file:///Users/medea/opt/anaconda3/envs/finalproject/lib/python3.9/site-packages/sqlalchemy/engine/base.py?line=1787'>1788</a>         self.dialect.do_executemany(
#    <a href='file:///Users/medea/opt/anaconda3/envs/finalproject/lib/python3.9/site-packages/sqlalchemy/engine/base.py?line=1788'>1789</a>             cursor, statement, parameters, context
# ...

# %%
columns = ["past_books", "past_seats"]
students.drop(columns=columns, inplace=True)

# %%
students.to_sql('students', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 100

# %%
layout.to_sql('layout', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 241

# %%
seats.to_sql('seats', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 104
