# %% [markdown]
# ## Student Database preparation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
students =  pd.read_excel("Data/students.xls")

# %%
students["email"] = students["student_id"].astype("str") +  "@unilibrary.com"

# %%
students["past_seats"] = np.empty((len(students), 0)).tolist()

# %%
students["past_books"] = np.empty((len(students), 0)).tolist()

# %%
students
# Out:
#     student_id  password  total_time_spent past_seats past_books  \
# 0       123456   1234560                 0         []         []
# 1       123457   1234570                 0         []         []
# 2       123458   1234580                 0         []         []
# 3       123459   1234590                 0         []         []
# 4       123460   1234600                 0         []         []
# ..         ...       ...               ...        ...        ...
# 95      123551   1235510                 0         []         []
# 96      123552   1235520                 0         []         []
# 97      123553   1235530                 0         []         []
# 98      123554   1235540                 0         []         []
# 99      123555   1235550                 0         []         []
#
#     current_seat  time_spent                  email
# 0              0           0  123456@unilibrary.com
# 1              0           0  123457@unilibrary.com
# ...

# %%
students.to_pickle("students.p")
